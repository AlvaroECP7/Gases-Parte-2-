# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvaroECP7/Gases-Parte-2-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install drawdata

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from drawdata import draw_scatter, draw_histogram, draw_line

draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("data (2).csv")
df
# Out:
#               x           y  z
# 0     62.068535  454.670006  a
# 1     88.972941  511.455072  a
# 2     34.743335  469.287787  a
# 3     95.154763  482.847968  a
# 4     42.339175  502.070105  a
# ..          ...         ... ..
# 198  687.381766   58.777963  a
# 199  664.934449   48.780240  a
# 200  701.011872   90.315994  a
# 201  705.898555   12.999050  a
# 202  724.833757   83.567005  a
#
# [203 rows x 3 columns]

# %%
df['y_inversa'] = 1 / df['y']

coefficients = np.polyfit(df['x'], df['y_inversa'], 1)
linea_tendencia_inversa = np.poly1d(coefficients)

plt.plot(df['x'], df["y"], label='Datos', marker='o', linestyle='None', color='green')

x_tendencia_inversa = np.linspace(df['x'].min(), df['x'].max(), 100)
y_tendencia_inversa = linea_tendencia_inversa(x_tendencia_inversa)
plt.plot(x_tendencia_inversa, y_tendencia_inversa, label='Regresión lineal', color='blue', linewidth=4.0)


plt.xlabel('Volumen (litros)')
plt.ylabel('Presión (atm)')
plt.title('Gráfica Ley de Boyle')

plt.grid(True)
plt.legend()

plt.show()

# %%
df = pd.read_csv("data (3).csv")
df
# Out:
#               x           y  z
# 0     20.489679  109.911542  a
# 1    -20.613017  104.129731  a
# 2      9.048487  113.356506  a
# 3    -48.348194   99.009584  a
# 4     -4.999266  104.380669  a
# ..          ...         ... ..
# 233  689.225383  407.673790  a
# 234  692.325202  479.885458  a
# 235  747.209618  508.487372  a
# 236  718.054947  441.287039  a
# 237  700.615230  481.884157  a
#
# [238 rows x 3 columns]

# %%
coefficients = np.polyfit(df['x'], df['y'], 1)
linea_tendencia = np.poly1d(coefficients)

plt.plot(df['x'], df['y'], label='Datos Originales', marker='o', linestyle='None')

x_tendencia = np.linspace(df['x'].min(), df['x'].max(), 100)
y_tendencia = linea_tendencia(x_tendencia)
plt.plot(x_tendencia, y_tendencia, label='Línea de Tendencia', color='red', linewidth=4.0)

plt.xlabel('Temperatura en Kelvin')
plt.ylabel('Volumen en mililitros')
plt.title('Gráfica Ley de Charles')

plt.grid(True)
plt.legend()

plt.show()

# %%
df = pd.read_csv("data (4).csv")
df
# Out:
#               x           y  z
# 0    135.812575   83.589346  a
# 1    141.202220  100.574160  a
# 2    177.512691   80.422959  a
# 3    167.514550   83.636039  a
# 4    134.069070  103.564754  a
# ..          ...         ... ..
# 275  751.115606  484.547077  a
# 276  657.744696  498.460813  a
# 277  741.582730  477.455853  a
# 278  762.289161  474.374433  a
# 279  668.278468  469.869076  a
#
# [280 rows x 3 columns]

# %%
coefficients = np.polyfit(df['x'], df['y'], 1)
linea_tendencia = np.poly1d(coefficients)

plt.plot(df['x'], df['y'], label='Datos Originales', marker='o', linestyle='None', color="orange")

x_tendencia = np.linspace(df['x'].min(), df['x'].max(), 100)
y_tendencia = linea_tendencia(x_tendencia)
plt.plot(x_tendencia, y_tendencia, label='Línea de Tendencia', color='red', linewidth=4.0)

plt.xlabel('Temperatura en Kelvin')
plt.ylabel('Volumen en mililitros')
plt.title('Gráfica Ley de Charles')

plt.grid(True)
plt.legend()

plt.show()

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df4 = pd.read_csv("data (7).csv")
df4
# Out:
#          x       y  z
# 0    0.000  0.0692  a
# 1    0.025  0.1432  a
# 2    0.050  0.2212  a
# 3    0.075  0.2952  a
# 4    0.100  0.4292  a
# ..     ...     ... ..
# 155  0.875  0.3152  d
# 156  0.900  0.3032  d
# 157  0.925  0.2952  d
# 158  0.950  0.2852  d
# 159  0.975  0.2832  d
#
# [160 rows x 3 columns]

# %%
fig = plt.figure(figsize=(8,5))
plt.xlabel('Velocidad (m/s)')
plt.ylabel('Num. moleculas')
plt.title('Velocidad vs num. moleculas')
plt.scatter(df4["x"],df4["y"])

plt.plot(df4["x"],df4["y"],color="red")

# %%
import requests
from bs4 import BeautifulSoup

url = "https://es.wikipedia.org/wiki/Gases_nobles"
response = requests.get(url)

if response.status_code == 200:

    soup = BeautifulSoup(response.text, 'html.parser')

    tabla = soup.find('table', {'class': 'wikitable'})

    df = pd.read_html(str(tabla))[0]

    df = df.rename(columns=df.iloc[0]).drop(df.index[0])

    print(df.head())

else:
    print("No se pudo obtener la página web.")
# Out:
#              Número atómico        2       10       18       36       54  \
# 1       Nombre del elemento    Helio     Neón    Argón  Kriptón    Xenón
# 2          Densidad (kg/m³)    01785    09002    17818     3708     5851
# 3        Radio atómico (nm)     0050     0070     0094     0109     0130
# 4  Punto de ebullición (°C)  –268,83  –245,92  –185,81  –151,70  –106,60
# 5      Punto de fusión (°C)     –272  –248,52   –189,6     –157   –111,5
#
#       86       118
# 1  Radón  Oganesón
# 2   9970      1365
# 3   0152         —
# 4    –62    47~107
# 5    –71       NaN
